# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Clustering-der-Entscheidungsgründe" data-toc-modified-id="Clustering-der-Entscheidungsgründe-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Clustering der Entscheidungsgründe</a></span><ul class="toc-item"><li><span><a href="#Datenvorbereitung" data-toc-modified-id="Datenvorbereitung-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Datenvorbereitung</a></span><ul class="toc-item"><li><span><a href="#Datenimport" data-toc-modified-id="Datenimport-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Datenimport</a></span></li><li><span><a href="#Datenaufbereitung" data-toc-modified-id="Datenaufbereitung-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Datenaufbereitung</a></span></li><li><span><a href="#Vektorisierung" data-toc-modified-id="Vektorisierung-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Vektorisierung</a></span></li></ul></li><li><span><a href="#Clustering-mit-k-means" data-toc-modified-id="Clustering-mit-k-means-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Clustering mit k-means</a></span><ul class="toc-item"><li><span><a href="#Initialisierung-&amp;-Training" data-toc-modified-id="Initialisierung-&amp;-Training-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Initialisierung &amp; Training</a></span></li><li><span><a href="#Clusterzugehörigkeit-der-Trainingsdokumente" data-toc-modified-id="Clusterzugehörigkeit-der-Trainingsdokumente-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Clusterzugehörigkeit der Trainingsdokumente</a></span></li><li><span><a href="#Häufigste-Wörter" data-toc-modified-id="Häufigste-Wörter-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Häufigste Wörter</a></span></li></ul></li><li><span><a href="#Visualisierung-der-Ergebnisse" data-toc-modified-id="Visualisierung-der-Ergebnisse-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Visualisierung der Ergebnisse</a></span><ul class="toc-item"><li><span><a href="#PCA-mit-2-Komponenten" data-toc-modified-id="PCA-mit-2-Komponenten-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>PCA mit 2 Komponenten</a></span></li><li><span><a href="#PCA-mit-3-Komponenten" data-toc-modified-id="PCA-mit-3-Komponenten-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>PCA mit 3 Komponenten</a></span></li></ul></li><li><span><a href="#Evakluation-der-Ergebnisse" data-toc-modified-id="Evakluation-der-Ergebnisse-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Evakluation der Ergebnisse</a></span><ul class="toc-item"><li><span><a href="#Intra-Cluster-Variance" data-toc-modified-id="Intra-Cluster-Variance-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Intra-Cluster-Variance</a></span></li><li><span><a href="#Silhouette-Score" data-toc-modified-id="Silhouette-Score-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Silhouette-Score</a></span></li><li><span><a href="#Silhouette-Plot" data-toc-modified-id="Silhouette-Plot-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Silhouette Plot</a></span></li><li><span><a href="#Calinski-Harabaz-Score" data-toc-modified-id="Calinski-Harabaz-Score-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Calinski-Harabaz Score</a></span></li><li><span><a href="#Optimierung-der-Clusteranzahl" data-toc-modified-id="Optimierung-der-Clusteranzahl-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Optimierung der Clusteranzahl</a></span></li></ul></li><li><span><a href="#Fazit" data-toc-modified-id="Fazit-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Fazit</a></span></li></ul></li><li><span><a href="#Clustering-der-Verbesserungsvorschläge" data-toc-modified-id="Clustering-der-Verbesserungsvorschläge-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Clustering der Verbesserungsvorschläge</a></span><ul class="toc-item"><li><span><a href="#Datenvorbereitung" data-toc-modified-id="Datenvorbereitung-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Datenvorbereitung</a></span><ul class="toc-item"><li><span><a href="#Datenimport" data-toc-modified-id="Datenimport-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Datenimport</a></span></li><li><span><a href="#Datenaufbereitung" data-toc-modified-id="Datenaufbereitung-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Datenaufbereitung</a></span></li><li><span><a href="#Vektorisierung" data-toc-modified-id="Vektorisierung-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Vektorisierung</a></span></li></ul></li><li><span><a href="#Clustering-mit-k-means" data-toc-modified-id="Clustering-mit-k-means-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Clustering mit k-means</a></span><ul class="toc-item"><li><span><a href="#Initialisierung-&amp;-Training" data-toc-modified-id="Initialisierung-&amp;-Training-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Initialisierung &amp; Training</a></span></li><li><span><a href="#Clusterzugehörigkeit-der-Trainingsdokumente" data-toc-modified-id="Clusterzugehörigkeit-der-Trainingsdokumente-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Clusterzugehörigkeit der Trainingsdokumente</a></span></li><li><span><a href="#Häufigste-Wörter" data-toc-modified-id="Häufigste-Wörter-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Häufigste Wörter</a></span></li></ul></li><li><span><a href="#Visualisierung-der-Ergebnisse" data-toc-modified-id="Visualisierung-der-Ergebnisse-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Visualisierung der Ergebnisse</a></span><ul class="toc-item"><li><span><a href="#PCA-mit-2-Komponenten" data-toc-modified-id="PCA-mit-2-Komponenten-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>PCA mit 2 Komponenten</a></span></li><li><span><a href="#PCA-mit-3-Komponenten" data-toc-modified-id="PCA-mit-3-Komponenten-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>PCA mit 3 Komponenten</a></span></li></ul></li><li><span><a href="#Evakluation-der-Ergebnisse" data-toc-modified-id="Evakluation-der-Ergebnisse-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Evakluation der Ergebnisse</a></span><ul class="toc-item"><li><span><a href="#Intra-Cluster-Variance" data-toc-modified-id="Intra-Cluster-Variance-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Intra-Cluster-Variance</a></span></li><li><span><a href="#Silhouette-Score" data-toc-modified-id="Silhouette-Score-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Silhouette-Score</a></span></li><li><span><a href="#Silhouette-Plot" data-toc-modified-id="Silhouette-Plot-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Silhouette Plot</a></span></li><li><span><a href="#Calinski-Harabaz-Score" data-toc-modified-id="Calinski-Harabaz-Score-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Calinski-Harabaz Score</a></span></li><li><span><a href="#Optimierung-der-Clusteranzahl" data-toc-modified-id="Optimierung-der-Clusteranzahl-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Optimierung der Clusteranzahl</a></span></li></ul></li><li><span><a href="#Fazit" data-toc-modified-id="Fazit-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Fazit</a></span></li></ul></li></ul></div>

# %% [markdown]
# Hilfsfunktionen und Einstellungen

# %%
# %matplotlib inline

# for pretty printing
import pprint as pp

# IPython (Jupyter) setting: 
# Print out every value instead of just "last_expr" (default)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Clustering der Entscheidungsgründe

# %% [markdown]
# ## Datenvorbereitung

# %% [markdown]
# ### Datenimport

# %% [markdown]
# Daten mit get_clustering_data aus DB laden.

# %%
import sqlite3
import pandas as pd
import os.path

dbPath = "database/bachelor_umfrage.db"

def get_clustering_data(where = None, table_name="clustering"):
    df = pd.DataFrame()
    if os.path.isfile(dbPath):
        conn = sqlite3.connect(dbPath)
        sql = "SELECT * FROM " + table_name
        sql += " WHERE " + where
        df = pd.read_sql_query(sql, conn)
    else:
        print("Datenbank oder Tabelle konnte nicht gefunden werden.")
    return df

reason_where = "Gründe IS NOT NULL"
reason_df = get_clustering_data(reason_where, table_name="clustering")
reason_df.sample(5)
# Out:
#      AntwortID Geschlecht            Studiengang MINTFach  \
# 192   62573156   Weiblich         Soziale Arbeit     nein
# 249   62589267   Weiblich         Soziale Arbeit     nein
# 133   62538030   Männlich  Wirtschaftsinformatik       ja
# 59    62507429   Männlich      Bauingenieurwesen       ja
# 340   62610437   Weiblich         Soziale Arbeit     nein
#
#                     Qualifikation GeborenAusland ElternAusland  \
# 192     allgemeine Hochschulreife           None             1
# 249     allgemeine Hochschulreife           None          None
# 133  fachgebundene Hochschulreife           None             1
# 59   fachgebundene Hochschulreife           None             1
# 340     allgemeine Hochschulreife           None             1
#
#     GeborenDeutschland MINTStudiumEltern StudiumEltern  \
# 192               None                 1          None
# 249                  1                 1          None
# 133               None                 1          None
# ...

# %% [markdown]
# ### Datenaufbereitung

# %%
import spacy

nlp = spacy.load('de')

# define space nlp with just the tagger (includes lemmatizer)
nlp_tagger = spacy.load('de', disable=['parser', 'ner'])

# %% [markdown]
# Beschränkung auf Nomen für das Clustering.

# %%
import string

def get_stopwords():
    with open("stopwords_de.txt", encoding="utf-8") as file:
        stopwords = file.read().splitlines()
        stopwords += ['studium', 'studiengang', 'mint']
    return set(stopwords)

stopwords = get_stopwords()
stopwords = stopwords.union(set(string.punctuation))

def pos_tokenizer(text):
    spacy_doc = nlp_tagger(text)
    pos_list=['NOUN', 'PROPN']
    
    tokens = [token.lemma_ for token in spacy_doc if token.pos_ in pos_list]
    tokens = [token for token in tokens if token.lower() not in stopwords]
    return tokens

# %% [markdown]
# Tokenisierung mit anschließender Speicherung in das Dataframe.

# %%
reason_df['tokens'] = reason_df['Gründe'].map(lambda t: ' '.join(pos_tokenizer(t)))

# %%
pd.set_option('max_colwidth', -1)
reason_df[['Gründe', 'tokens']].sample(5)
pd.reset_option('max_colwidth')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Gründe  \
# 242  Wenig Interesse
# ...

# %% [markdown]
# ### Vektorisierung

# %%
# Test für Männer & Frauen Gruppierung
# Wort Talent kommt vor
female_df = reason_df[reason_df["Geschlecht"] == "Weiblich"]
# sehr oft Interesse
male_df = reason_df[reason_df["Geschlecht"] == "Männlich"]

# Test für Qualifikation
# Verständnis kommt öfters vor
abi_df = reason_df[reason_df["Qualifikation"] == "allgemeine Hochschulreife"]
# Gehalt kommt öfters vor
fach_abi_df = reason_df[(reason_df["Qualifikation"] == "fachgebundene Hochschulreife")
                     | (reason_df["Qualifikation"] == "Fachhochschulreife")]

# Test für Studienpionier
# Wenig Unterschied zum gesamt Clustering
pioneer_df = reason_df[reason_df["Studienpionier"] == "1"]

# %% [markdown]
# Ermittlung der TF- und TF-IDF-Matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# TF-Vectorizer
count_vect = CountVectorizer(lowercase=False, min_df=10, max_df=0.5)
X_train_tf = count_vect.fit_transform(reason_df.tokens)
#X_train_tf = count_vect.fit_transform(female_df.tokens)
print("%d x %d Count-Matrix (= BoW = TF)" % X_train_tf.shape)
# Out:
# 504 x 39 Count-Matrix (= BoW = TF)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# TF-IDF Vectorizer
tfidf_transformer = TfidfTransformer(sublinear_tf=True, norm="l2")
X_train_tfidf = tfidf_transformer.fit_transform(X_train_tf)

print("%d x %d TF-IDF-Matrix" % X_train_tfidf.shape)
# Out:
# 504 x 39 TF-IDF-Matrix

# %% [markdown]
# Wert wird zunächst auf TD-IDF-Matrix gesetzt. Um später andere Matrix zu testen wird dieser Wert geändert.

# %%
X_train = X_train_tfidf

# %% [markdown]
# ## Clustering mit k-means

# %% [markdown]
# In diesem Kapitel sollen mit Hilfe des Clustering mit k-means die Gründe für oder gegen die Wahl von MINT-Fächern analysiert werden.

# %% [markdown]
# ### Initialisierung & Training

# %% [markdown]
# Setzen der Anzahl der Cluster

# %%
n_clusters = 4

# %%
from sklearn.cluster import KMeans

k_means = KMeans(n_clusters=n_clusters, init='k-means++')
k_means.fit(X_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### Clusterzugehörigkeit der Trainingsdokumente

# %% [markdown]
# Aufteilung der Dokumente zu den einzelnen Clustern

# %%
import numpy as np

cluster_count = np.unique(k_means.labels_, return_counts=True)
cluster_count
# Out:
# (array([0, 1, 2, 3]), array([ 64, 104, 292,  44], dtype=int64))

# %% [markdown]
# Anfügen der Clusterzuordnung an das Dataframe

# %%
reason_df['cluster'] = k_means.labels_
#female_df['cluster'] = k_means.labels_

# %%
reason_df.groupby(['cluster']).agg({'AntwortID':'count'}).plot(kind='bar', figsize=(6,4));
#female_df.groupby(['cluster']).agg({'AntwortID':'count'}).plot(kind='bar', figsize=(6,4));

# %% [markdown]
# ### Häufigste Wörter

# %% [markdown]
# Ausgabe der 10 häufigsten Wörter je Cluster.

# %%
feature_names = count_vect.get_feature_names()
counts_df = pd.DataFrame(X_train.toarray(), columns=feature_names)

# %%
def get_most_important_words(counts_df, labels):
    # Kopie des DataFrames anlegen, Werte werden manipuliert
    d = counts_df.copy()
    
    d["cluster"] = labels
    # Gruppierung nach Clusterlabel und Summierung der Häufigkeiten
    d = d.groupby(["cluster"]).sum()
    # Transponierung, jetzt sind die Cluster die Spalten und die Terme in den Zeilen
    dt = d.T
    
    # Spalten-Namen vergeben: Cluster 0 ... k-1
    dt.columns = ["Cluster %d" % label for label in np.unique(labels)]
    
    # Ausgabe der 10 häufigsten Worte je Cluster
    for col in dt.columns: 
        # sort_values sortiert nach einer Spalte
        tmp = dt.sort_values(by=col, ascending=False)
        tmp = tmp[[col]]
        display(tmp.head(10))

# %%
get_most_important_words(counts_df, k_means.labels_)
# Out:
#             Cluster 0
# Bereich     39.083342
# Interesse    6.895339
# MINT         5.938308
# Fach         4.203293
# Arbeit       4.030808
# Physik       3.574804
# Informatik   3.555193
# Erwägung     3.249046
# fächern      3.117013
# Ausbildung   3.055222
#                      Cluster 1
# Interesse            66.332762
# Fach                  5.851405
# Technik               5.733373
# schulen               5.677580
# Informatik            5.089820
# berufen               4.872838
# Naturwissenschaften   4.534967
# Ausbildung            3.988813
# Berufsaussichten      3.778307
# Mathe                 3.271974
#             Cluster 2
# schulen     22.919159
# fächern     22.077427
# MINT        20.333421
# Fach        19.194294
# Erwägung    16.690085
# Informatik  16.158166
# berufen     15.440440
# fachen      13.220126
# Mathe       13.159160
# Richtung    11.924871
#                      Cluster 3
# Chemie               24.256290
# schulen               6.344983
# ...

# %% [markdown]
# ## Visualisierung der Ergebnisse

# %% [markdown]
# In diesem Kapitel sollen die Ergebnisse durch PCA mit 2 und 3 Komponenten dargestellt werden

# %% [markdown]
# ### PCA mit 2 Komponenten

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train.toarray())

# %%
centers_pca = pca.transform(k_means.cluster_centers_)

# Darstellung
plt.rcParams["figure.figsize"] = (16, 9)
plt.style.use("seaborn-whitegrid")
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=k_means.labels_, cmap="tab20c", s=7)

# Darstellung der Clusterzentren
plt.scatter(centers_pca[:, 0], centers_pca[:, 1], marker="*", c="#ffcc5c", s=400);

# %% [markdown]
# ### PCA mit 3 Komponenten

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_train.toarray())
centers_pca = pca.transform(k_means.cluster_centers_)

# %%
plt.rcParams["figure.figsize"] = (16, 9)
plt.style.use("seaborn-whitegrid")
fig = plt.figure()
ax = Axes3D(fig)

# Panes transparent darstellen
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=k_means.labels_, cmap="tab20c")
# Clusterzentren
ax.scatter(centers_pca[:, 0], centers_pca[:, 1], centers_pca[:, 2], marker="*", c="#ffcc5c", s=1200);

# Perspektive einstellen
ax.view_init(20, 30)
plt.draw();

# %% [markdown]
# ## Evakluation der Ergebnisse

# %% [markdown]
# Um zu bewerten, wie gut das Clustering ist werden im folgenden verschiedene Gütemaße berechnet.

# %% [markdown]
# ### Intra-Cluster-Variance

# %%
# Erstelle Matrix, die für jedes Dokument den Vektor 
# des entsprechenden Centroids enthält
X_centroids = k_means.cluster_centers_[k_means.labels_]
# ICV errechnet sich dann aus (X-X_centroids)**2

# %%
def icv_score(X, X_centroids):
    D_squared = np.square(X-X_centroids)
    return np.sum(np.sum(D_squared, axis=1))

# %%
icv_score(X_train, X_centroids)
# Out:
# 333.21264570784007

# %% [markdown]
# ICV groß => Cluster sind nicht kompakt

# %% [markdown]
# ### Silhouette-Score

# %%
from sklearn.metrics import silhouette_score

silhouette_score(X_train.toarray(), k_means.labels_, metric="euclidean")
# Out:
# 0.13061282126875584

# %% [markdown]
# Silhouette-Score nahe 0 => schlecht seperierbare Cluster

# %% [markdown]
# ### Silhouette Plot

# %%
def visualize_silhouette(X, cluster_labels, cluster_centers, n_clusters):
    import numpy as np
    from sklearn.metrics import silhouette_samples, silhouette_score
    import matplotlib.cm as cm
    import matplotlib.pyplot as plt
    from sklearn.decomposition import PCA

    pca = PCA(n_components=2)
    pc = pca.fit_transform(X)
    centers_transformed = pca.transform(cluster_centers)

    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # Der Silhouette Plot ist der erste Subplot
    # Der Silhouette Score kann zwar Werte zwischen -1 und 1 annehmen,
    # nachdem der Score in diesem Beispiel jedoch sehr niedrig ist, wird
    # der Wertebereich der Grafik zur besseren Darstellbarkeit auf [-0.05, 0.15] eingeschränkt
    ax1.set_xlim([-0.05, 0.15])
    
    # Fügt Leerraum zwischen den Silhouette Plots für die einzelnen Cluster ein
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Berechnung des Silhouette Scores
    silhouette_score = silhouette_score(X, cluster_labels)
    print("Silhouette Score für n_clusters = {}: {}".format(n_clusters, silhouette_score))

    # Berechnet den Silhouette Score für jedes der 1.000 Samples einzeln 
    # (liefert Array mit 1.000 Scores)   
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregation der einzelnen Scores für cluster i und absteigende Sortierung
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.tab20c(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Setzt das Clusterlabel mittig links and den jeweiligen Silhouette Plot
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        
        # Berechnet einen neuen Wert für y_lower für den nächsten Plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("Silhouette Plot je Cluster.")
    ax1.set_xlabel("Silhouette Koeffizient")
    ax1.set_ylabel("Cluster Label")

    # Vertikale Linie, die den Mittelwert über alle Werte (den eigentlichen Silhouette Score) angibt
    ax1.axvline(x=silhouette_score, color="red", linestyle="--")

    ax1.set_yticks([])  # Y-Achsenbezeichnungen entfernen
    ax1.set_xticks([-0.05, 0, 0.05, 0.1, 0.15])


    # Zweiter Plot (rechts), der die Cluster mit Hilfe von PCA zweidimensional darstellt
    colors = cm.tab20c(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(pc[:, 0], pc[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling der Cluster im rechten Plot
    ax2.scatter(centers_transformed[:, 0], centers_transformed[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers_transformed):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("Geclusterte Daten mit zwei Hauptkomponenten (PCA)")
    ax2.set_xlabel("Erste Hauptkomponente")
    ax2.set_ylabel("Zweite Hauptkomponente")

    plt.suptitle(("Silhouette Analyse mit n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold');

# %%
X = X_train.toarray()
cluster_labels = k_means.labels_
cluster_centers = k_means.cluster_centers_
n_clusters = k_means.n_clusters

# %%
visualize_silhouette(X, cluster_labels, cluster_centers, n_clusters)
# Out:
# Silhouette Score für n_clusters = 4: 0.13061282126875584

# %% [markdown]
# Nur wenige Datensätze mit negativem Score -> nur wenige falsch zugeordnet. Ein Cluster viel größer als die anderen -> vermutlich nicht die Optimale Clusteranzahl.

# %% [markdown]
# ### Calinski-Harabaz Score

# %%
from sklearn.metrics import calinski_harabaz_score

calinski_harabaz_score(X_train_tfidf.toarray(), k_means.labels_)
# Out:
# 32.58082719118547

# %% [markdown]
# Je dichter die Daten zusammen & je besser Cluster voneinander getrennt, desto höher der Score.

# %% [markdown]
# ### Optimierung der Clusteranzahl

# %%
def find_opt_k(X, range_n_clusters):
    import pandas as pd 
    import numpy as np
    import matplotlib.pyplot as plt
    from sklearn import metrics
    from sklearn.cluster import KMeans
    from sklearn.decomposition import PCA
    
    plt.rcParams["figure.figsize"] = (16, 9)
    plt.style.use("seaborn-whitegrid")
    
    plot_count = 1
    n_components = 2
    
    # Durchführung PCA
    pca = PCA(n_components=n_components)
    principal_components = pca.fit_transform(X.toarray())
    cols = []
    for i in range(n_components):
        cols.append("component" + str(i))
    pca_df = pd.DataFrame(data = principal_components, columns = cols)
    
    for n_clusters in range_n_clusters:
        
        # Durchführung K-Means für die aktuelle Clusteranzahl
        k_means = KMeans(n_clusters=n_clusters)
        k_means.fit(X)
        labels = k_means.labels_
        
        # Plot der Ergebnisse in einem 3x3 Raster
        plt.subplot(3,3,plot_count)
        plt.scatter(pca_df.iloc[:,0], pca_df.iloc[:,1], c=labels, cmap="tab20c", s=7)
        plt.title("n_clusters = " + str(n_clusters))
        
        # Berechnung der Performancemaße
        silhouette_score = metrics.silhouette_score(X.toarray(), labels)
        harabaz = metrics.calinski_harabaz_score(X.toarray(), labels)

        print("{:d} Cluster: Silhouette = {:.6f}, Calinski-Harabaz = {:.2f}".format(n_clusters, silhouette_score, harabaz))
        plot_count += 1

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# Vorgegebene Clusteranzahlen
range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]

find_opt_k(X_train_tfidf, range_n_clusters)
# Out:
# 2 Cluster: Silhouette = 0.105246, Calinski-Harabaz = 43.94
# 3 Cluster: Silhouette = 0.112594, Calinski-Harabaz = 36.31
# 4 Cluster: Silhouette = 0.131758, Calinski-Harabaz = 32.72
# 5 Cluster: Silhouette = 0.142452, Calinski-Harabaz = 30.09
# 6 Cluster: Silhouette = 0.148457, Calinski-Harabaz = 28.56
# 7 Cluster: Silhouette = 0.157802, Calinski-Harabaz = 26.84
# 8 Cluster: Silhouette = 0.172599, Calinski-Harabaz = 28.21
# 9 Cluster: Silhouette = 0.180504, Calinski-Harabaz = 26.73
# 10 Cluster: Silhouette = 0.191461, Calinski-Harabaz = 26.71

# %% [markdown]
# Test mit TF-Matrix

# %%
from sklearn.cluster import KMeans

X_train = X_train_tf

n_clusters = 6
k_means_best = KMeans(n_clusters=n_clusters, init='k-means++')
k_means_best.fit(X_train)

X = X_train.toarray()
cluster_labels = k_means_best.labels_
cluster_centers = k_means_best.cluster_centers_

visualize_silhouette(X, cluster_labels, cluster_centers, n_clusters)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
# Silhouette Score für n_clusters = 6: 0.1397620790435933

# %% [markdown]
# ## Fazit

# %% [markdown]
# Es konnten bessere Ergebnisse mit der TF-IDF Matrix festgestellt werden.
#
# Bei Betrachtung der 10 häufigsten Wörter je Cluster tauchen einige Wörter in mehreren Clustern auf:
# - Interesse
# - Schulen
# - Fach
# - Berufsaussichten
# - Mathe (& Chemie & Physik)
# - Erwägung
# - Ausbildung
#
# Daraus lässt sich schließen, dass vor allem das Fachinteresse, die Schulzeit sowie die Berufsaussichten ausschlaggebende Faktoren bei der Wahl des Studiengangs waren. Ebenso scheinen einige Studenten vorher bereits eine Ausbildung im Bereich ihres Studiengangs absolviert zu und daher diesen gewählt zu haben. Interessant ist auch die Häufigkeit des Wortes Erwägung. Diese zeigt, dass es einige Studenten gibt, die ein MINT-Fach wählen wollten, es jedoch aus bestimmten Gründen doch nicht getan haben.
#
# Beim Clustering von einzelnen Gruppen wurden folgende Veränderungen bei den häufigsten Wörtern festgestellt:
#
# **Frauen & Männer**
# - Frauen: Wort Talent kommt vor
# - Männer: sehr oft Interesse
#
# Aus dieser Verteilung lässt sich schließen, dass Männer bei ihren Studiengangs oft nach fachlichem Interesse wählen. Bei Frauen scheint dies auch der Fall zu sein, jedoch scheinen viele den Studiengang aufgrund ihres Talents im dazugehörigen Themenbereich auszusuchen.
#
# **Qualifikation**
# - Allgemeine Hochschulreife: Verständnis kommt öfters vor
# - Fachgebundene Hochschulreife / Fachhochschulreife: Gehalt kommt öfters vor
#
# Hieraus lässt sich ableiten, dass Studenten mit allgemeiner Hochschulreife mehr auf das Verständnis (des Themenbereichts) achten, wenn sie einen Studiengang wählen. Bei Studenten mit fachgebundener Hochschulreife hingegen nimmt das Gehalt des zukünftigen Berufs eine wichtigere Rolle ein als beim Rest.
#
# **Studienpionier**
# - kaum Veränderungen

# %% [markdown]
# # Clustering der Verbesserungsvorschläge

# %% [markdown]
# ## Datenvorbereitung

# %% [markdown]
# ### Datenimport

# %% [markdown]
# Daten mit get_clustering_data aus DB laden.

# %%
import sqlite3
import pandas as pd
import os.path

dbPath = "database/bachelor_umfrage.db"

def get_clustering_data(where=None, table_name="clustering"):
    df = pd.DataFrame()
    if os.path.isfile(dbPath):
        conn = sqlite3.connect(dbPath)
        sql = "SELECT * FROM " + table_name
        sql += " WHERE " + where
        df = pd.read_sql_query(sql, conn)
    else:
        print("Datenbank oder Tabelle konnte nicht gefunden werden.")
    return df

suggestions_where = "Verbesserungsvorschläge IS NOT NULL"
suggestions_df = get_clustering_data(suggestions_where, table_name="clustering")
suggestions_df.sample(5)
# Out:
#      AntwortID Geschlecht                                        Studiengang  \
# 166   62579418   Weiblich                                     Soziale Arbeit
# 179   62586894   Weiblich  Soziale Arbeit: Erziehung und Bildung im Leben...
# 145   62573088   Weiblich                                     Soziale Arbeit
# 193   62590489   Männlich                              Wirtschaftsinformatik
# 32    62500623   Weiblich                                             Design
#
#     MINTFach                 Qualifikation GeborenAusland ElternAusland  \
# 166     nein                    Fachabitur           None          None
# 179     nein        beruflich qualifiziert           None          None
# 145     nein  fachgebundene Hochschulreife           None             1
# 193       ja  fachgebundene Hochschulreife              1          None
# 32      nein  fachgebundene Hochschulreife           None          None
#
#     GeborenDeutschland MINTStudiumEltern StudiumEltern  \
# ...

# %% [markdown]
# ### Datenaufbereitung

# %%
import spacy

nlp = spacy.load('de')

# define space nlp with just the tagger (includes lemmatizer)
nlp_tagger = spacy.load('de', disable=['parser', 'ner'])

# %% [markdown]
# Beschränkung auf Nomen für das Clustering.

# %%
import string

def get_stopwords():
    with open("stopwords_de.txt", encoding="utf-8") as file:
        stopwords = file.read().splitlines()
        stopwords += ['studium', 'studiengang', 'mint-fächer']
    return set(stopwords)

stopwords = get_stopwords()
stopwords = stopwords.union(set(string.punctuation))

def pos_tokenizer(text):
    spacy_doc = nlp_tagger(text)
    pos_list=['NOUN', 'PROPN']
    
    tokens = [token.lemma_ for token in spacy_doc if token.pos_ in pos_list]
    tokens = [token for token in tokens if token.lower() not in stopwords]
    return tokens

# %% [markdown]
# Tokenisierung mit anschließender Speicherung in das Dataframe.

# %%
suggestions_df['tokens'] = suggestions_df['Verbesserungsvorschläge'].map(lambda t: ' '.join(pos_tokenizer(t)))

# %%
pd.set_option('max_colwidth', -1)
suggestions_df[['Verbesserungsvorschläge', 'tokens']].sample(5)
pd.reset_option('max_colwidth')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Verbesserungsvorschläge  \
# 226  Organisation von einem mint tag mit workshops.
# ...

# %% [markdown]
# ### Vektorisierung

# %%
# Test für Männer & Frauen Gruppierung
# mehr Mädchen/Frauen als bei Männern
female_df = suggestions_df[suggestions_df["Geschlecht"] == "Weiblich"]
# mehr Vorlesung & Praxisbezug als bei Frauen
male_df = suggestions_df[suggestions_df["Geschlecht"] == "Männlich"]

# Test für Qualifikation
# mehr Praxisbezug als bei Fachabitur
abi_df = suggestions_df[suggestions_df["Qualifikation"] == "allgemeine Hochschulreife"]
# kaum Unterschiede
fach_abi_df = suggestions_df[(suggestions_df["Qualifikation"] == "fachgebundene Hochschulreife")
                         | (suggestions_df["Qualifikation"] == "Fachhochschulreife")]

# Test für Studienpionier
# kaum Unterschiede
pioneer_df = suggestions_df[suggestions_df["Studienpionier"] == "1"]

# %% [markdown]
# Ermittlung der TF- und TF-IDF-Matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer

# TF-Vectorizer
count_vect = CountVectorizer(lowercase=False, min_df=10, max_df=0.5)
X_train_tf = count_vect.fit_transform(suggestions_df.tokens)
#X_train_tf = count_vect.fit_transform(female_df.tokens)
print("%d x %d Count-Matrix (= BoW = TF)" % X_train_tf.shape)
# Out:
# 366 x 39 Count-Matrix (= BoW = TF)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# TF-IDF Vectorizer
tfidf_transformer = TfidfTransformer(sublinear_tf=True, norm="l2")
X_train_tfidf = tfidf_transformer.fit_transform(X_train_tf)

print("%d x %d TF-IDF-Matrix" % X_train_tfidf.shape)
# Out:
# 366 x 39 TF-IDF-Matrix

# %% [markdown]
# Wert wird zunächst auf TD-IDF-Matrix gesetzt. Um später andere Matrix zu testen wird dieser Wert geändert.

# %%
X_train = X_train_tfidf

# %% [markdown]
# ## Clustering mit k-means

# %% [markdown]
# In diesem Kapitel sollen mit Hilfe des Clustering mit k-means die Gründe für oder gegen die Wahl von MINT-Fächern analysiert werden.

# %% [markdown]
# ### Initialisierung & Training

# %% [markdown]
# Setzen der Anzahl der Cluster

# %%
n_clusters = 3

# %%
from sklearn.cluster import KMeans

k_means = KMeans(n_clusters=n_clusters, init='k-means++')
k_means.fit(X_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### Clusterzugehörigkeit der Trainingsdokumente

# %% [markdown]
# Aufteilung der Dokumente zu den einzelnen Clustern

# %%
import numpy as np

cluster_count = np.unique(k_means.labels_, return_counts=True)
cluster_count
# Out:
# (array([0, 1, 2]), array([252,  61,  53], dtype=int64))

# %% [markdown]
# Anfügen der Clusterzuordnung an das Dataframe

# %%
suggestions_df['cluster'] = k_means.labels_

# %%
suggestions_df.groupby(['cluster']).agg({'AntwortID':'count'}).plot(kind='bar', figsize=(6,4));

# %% [markdown]
# ### Häufigste Wörter

# %% [markdown]
# Ausgabe der 10 häufigsten Wörter je Cluster.

# %%
feature_names = count_vect.get_feature_names()
counts_df = pd.DataFrame(X_train.toarray(), columns=feature_names)

# %%
def get_most_important_words(counts_df, labels):
    # Kopie des DataFrames anlegen, Werte werden manipuliert
    d = counts_df.copy()
    
    d["cluster"] = labels
    # Gruppierung nach Clusterlabel und Summierung der Häufigkeiten
    d = d.groupby(["cluster"]).sum()
    # Transponierung, jetzt sind die Cluster die Spalten und die Terme in den Zeilen
    dt = d.T
    
    # Spalten-Namen vergeben: Cluster 0 ... k-1
    dt.columns = ["Cluster %d" % label for label in np.unique(labels)]
    
    # Ausgabe der 10 häufigsten Worte je Cluster
    for col in dt.columns: 
        # sort_values sortiert nach einer Spalte
        tmp = dt.sort_values(by=col, ascending=False)
        tmp = tmp[[col]]
        display(tmp.head(10))

# %%
get_most_important_words(counts_df, k_means.labels_)
# Out:
#              Cluster 0
# Schule       13.076760
# Frau         12.044659
# MINT         11.811101
# Thema         9.986742
# Bereich       8.530886
# Vorlesungen   8.198602
# Praxisbezug   8.025924
# Praxis        6.775812
# Schüler       6.298795
# Fach          6.169561
#             Cluster 1
# schulen     25.785421
# Interesse   10.132862
# Schüler      6.373374
# MINT         5.411760
# Lehrer       4.492472
# Unterricht   3.901490
# Mädchen      3.522163
# Kind         3.425983
# Chemie       3.222774
# Fach         2.849817
#               Cluster 2
# fächern       30.027937
# MINT           9.553782
# schulen        9.047637
# Mathe          4.070405
# Schüler        4.032858
# Fach           2.952507
# Physik         2.304800
# Studiengänge   2.282536
# Thema          2.197182
# berufen        1.953770

# %% [markdown]
# ## Visualisierung der Ergebnisse

# %% [markdown]
# In diesem Kapitel sollen die Ergebnisse durch PCA mit 2 und 3 Komponenten dargestellt werden

# %% [markdown]
# ### PCA mit 2 Komponenten

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train.toarray())

# %%
centers_pca = pca.transform(k_means.cluster_centers_)

# Darstellung
plt.rcParams["figure.figsize"] = (16, 9)
plt.style.use("seaborn-whitegrid")
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=k_means.labels_, cmap="tab20c", s=7)

# Darstellung der Clusterzentren
plt.scatter(centers_pca[:, 0], centers_pca[:, 1], marker="*", c="#ffcc5c", s=400);

# %% [markdown]
# ### PCA mit 3 Komponenten

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_train.toarray())
centers_pca = pca.transform(k_means.cluster_centers_)

# %%
plt.rcParams["figure.figsize"] = (16, 9)
plt.style.use("seaborn-whitegrid")
fig = plt.figure()
ax = Axes3D(fig)

# Panes transparent darstellen
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=k_means.labels_, cmap="tab20c")
# Clusterzentren
ax.scatter(centers_pca[:, 0], centers_pca[:, 1], centers_pca[:, 2], marker="*", c="#ffcc5c", s=1200);

# Perspektive einstellen
ax.view_init(20, 30)
plt.draw();

# %% [markdown]
# ## Evakluation der Ergebnisse

# %% [markdown]
# Um zu bewerten, wie gut das Clustering ist werden im folgenden verschiedene Gütemaße berechnet.

# %% [markdown]
# ### Intra-Cluster-Variance

# %%
# Erstelle Matrix, die für jedes Dokument den Vektor 
# des entsprechenden Centroids enthält
X_centroids = k_means.cluster_centers_[k_means.labels_]
# ICV errechnet sich dann aus (X-X_centroids)**2

# %%
def icv_score(X, X_centroids):
    D_squared = np.square(X-X_centroids)
    return np.sum(np.sum(D_squared, axis=1))

# %%
icv_score(X_train, X_centroids)
# Out:
# 200.25830033301196

# %% [markdown]
# ICV groß => Cluster sind nicht kompakt aber besser als bei vorherigem Clustering.

# %% [markdown]
# ### Silhouette-Score

# %%
from sklearn.metrics import silhouette_score

silhouette_score(X_train.toarray(), k_means.labels_, metric="euclidean")
# Out:
# 0.22237511604071225

# %% [markdown]
# Silhouette-Score nahe 0 => schlecht seperierbare Cluster. Aber besser als bei vorherigem Clustering.

# %% [markdown]
# ### Silhouette Plot

# %%
def visualize_silhouette(X, cluster_labels, cluster_centers, n_clusters):
    import numpy as np
    from sklearn.metrics import silhouette_samples, silhouette_score
    import matplotlib.cm as cm
    import matplotlib.pyplot as plt
    from sklearn.decomposition import PCA

    pca = PCA(n_components=2)
    pc = pca.fit_transform(X)
    centers_transformed = pca.transform(cluster_centers)

    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # Der Silhouette Plot ist der erste Subplot
    # Der Silhouette Score kann zwar Werte zwischen -1 und 1 annehmen,
    # nachdem der Score in diesem Beispiel jedoch sehr niedrig ist, wird
    # der Wertebereich der Grafik zur besseren Darstellbarkeit auf [-0.05, 0.15] eingeschränkt
    ax1.set_xlim([-0.05, 0.15])
    
    # Fügt Leerraum zwischen den Silhouette Plots für die einzelnen Cluster ein
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Berechnung des Silhouette Scores
    silhouette_score = silhouette_score(X, cluster_labels)
    print("Silhouette Score für n_clusters = {}: {}".format(n_clusters, silhouette_score))

    # Berechnet den Silhouette Score für jedes der 1.000 Samples einzeln 
    # (liefert Array mit 1.000 Scores)   
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregation der einzelnen Scores für cluster i und absteigende Sortierung
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.tab20c(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Setzt das Clusterlabel mittig links and den jeweiligen Silhouette Plot
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        
        # Berechnet einen neuen Wert für y_lower für den nächsten Plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("Silhouette Plot je Cluster.")
    ax1.set_xlabel("Silhouette Koeffizient")
    ax1.set_ylabel("Cluster Label")

    # Vertikale Linie, die den Mittelwert über alle Werte (den eigentlichen Silhouette Score) angibt
    ax1.axvline(x=silhouette_score, color="red", linestyle="--")

    ax1.set_yticks([])  # Y-Achsenbezeichnungen entfernen
    ax1.set_xticks([-0.05, 0, 0.05, 0.1, 0.15])


    # Zweiter Plot (rechts), der die Cluster mit Hilfe von PCA zweidimensional darstellt
    colors = cm.tab20c(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(pc[:, 0], pc[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

    # Labeling der Cluster im rechten Plot
    ax2.scatter(centers_transformed[:, 0], centers_transformed[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers_transformed):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("Geclusterte Daten mit zwei Hauptkomponenten (PCA)")
    ax2.set_xlabel("Erste Hauptkomponente")
    ax2.set_ylabel("Zweite Hauptkomponente")

    plt.suptitle(("Silhouette Analyse mit n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold');

# %%
X = X_train.toarray()
cluster_labels = k_means.labels_
cluster_centers = k_means.cluster_centers_
n_clusters = k_means.n_clusters

# %%
visualize_silhouette(X, cluster_labels, cluster_centers, n_clusters)
# Out:
# Silhouette Score für n_clusters = 3: 0.22237511604071225

# %% [markdown]
# Nur ein Cluster mit vielen Datensätzen mit negativem Score -> außer dort nur wenige falsch zugeordnet. Ein Cluster viel größer als die anderen -> vermutlich nicht die Optimale Clusteranzahl.

# %% [markdown]
# ### Calinski-Harabaz Score

# %%
from sklearn.metrics import calinski_harabaz_score

calinski_harabaz_score(X_train_tfidf.toarray(), k_means.labels_)
# Out:
# 24.88633607033799

# %% [markdown]
# Je dichter die Daten zusammen & je besser Cluster voneinander getrennt, desto höher der Score.

# %% [markdown]
# ### Optimierung der Clusteranzahl

# %%
def find_opt_k(X, range_n_clusters):
    import pandas as pd 
    import numpy as np
    import matplotlib.pyplot as plt
    from sklearn import metrics
    from sklearn.cluster import KMeans
    from sklearn.decomposition import PCA
    
    plt.rcParams["figure.figsize"] = (16, 9)
    plt.style.use("seaborn-whitegrid")
    
    plot_count = 1
    n_components = 2
    
    # Durchführung PCA
    pca = PCA(n_components=n_components)
    principal_components = pca.fit_transform(X.toarray())
    cols = []
    for i in range(n_components):
        cols.append("component" + str(i))
    pca_df = pd.DataFrame(data = principal_components, columns = cols)
    
    for n_clusters in range_n_clusters:
        
        # Durchführung K-Means für die aktuelle Clusteranzahl
        k_means = KMeans(n_clusters=n_clusters)
        k_means.fit(X)
        labels = k_means.labels_
        
        # Plot der Ergebnisse in einem 3x3 Raster
        plt.subplot(3,3,plot_count)
        plt.scatter(pca_df.iloc[:,0], pca_df.iloc[:,1], c=labels, cmap="tab20c", s=7)
        plt.title("n_clusters = " + str(n_clusters))
        
        # Berechnung der Performancemaße
        silhouette_score = metrics.silhouette_score(X.toarray(), labels)
        harabaz = metrics.calinski_harabaz_score(X.toarray(), labels)

        print("{:d} Cluster: Silhouette = {:.6f}, Calinski-Harabaz = {:.2f}".format(n_clusters, silhouette_score, harabaz))
        plot_count += 1

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# Vorgegebene Clusteranzahlen
range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]

find_opt_k(X_train_tfidf, range_n_clusters)
# Out:
# 2 Cluster: Silhouette = 0.205456, Calinski-Harabaz = 29.02
# 3 Cluster: Silhouette = 0.214314, Calinski-Harabaz = 23.23
# 4 Cluster: Silhouette = 0.238908, Calinski-Harabaz = 23.58
# 5 Cluster: Silhouette = 0.228387, Calinski-Harabaz = 18.89
# 6 Cluster: Silhouette = 0.266257, Calinski-Harabaz = 21.47
# 7 Cluster: Silhouette = 0.276812, Calinski-Harabaz = 21.13
# 8 Cluster: Silhouette = 0.288661, Calinski-Harabaz = 20.69
# 9 Cluster: Silhouette = 0.297579, Calinski-Harabaz = 20.09
# 10 Cluster: Silhouette = 0.308225, Calinski-Harabaz = 19.89

# %% [markdown]
# Test mit TF-Matrix

# %%
from sklearn.cluster import KMeans

X_train = X_train_tf

n_clusters = 6
k_means_best = KMeans(n_clusters=n_clusters, init='k-means++')
k_means_best.fit(X_train)

X = X_train.toarray()
cluster_labels = k_means_best.labels_
cluster_centers = k_means_best.cluster_centers_

visualize_silhouette(X, cluster_labels, cluster_centers, n_clusters)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
# Silhouette Score für n_clusters = 6: 0.29778343368085447

# %% [markdown]
# ## Fazit

# %% [markdown]
# Es konnten bessere Ergebnisse mit der TF-IDF Matrix festgestellt werden.
#
# Bei Betrachtung der 10 häufigsten Wörter je Cluster tauchen einige Wörter in mehreren Clustern auf:
# - Schulen
# - Interesse
# - Fach
# - Praxisbezug
# - Mathe (und andere Schulfächer)
# - Vorlesung
#
# Daraus lässt sich schließen, dass viele Studenten den Schulunterricht als größten Verbesserungsfaktor sehen. Darin sollte das Interesse der Schüler geweckt und Praxisbezug hergestellt werden. Aber auch die Vorlesungen scheinen in einigen Punkten verbesserungswürdig zu sein. Welche das sind lässt sich jedoch nicht durch das Clustering herausfinden.
#
# Beim Clustering von einzelnen Gruppen wurden folgende Veränderungen bei den häufigsten Wörtern festgestellt:
#
# **Frauen & Männer**
# - Frauen: mehr Mädchen/Frauen als bei Männern
# - Männer: mehr Vorlesung & Praxisbezug als bei Frauen
#
# Aus dieser Verteilung lässt sich schließen, dass Männer mehr Praxisbezug fordern und die Vorlesung für verbesserungswürdiger halten als die Frauen. Deren Vorschläge sind hingegen oft, besonders bei Mädchen das Interesse in der Schule zu wecken.
#
# **Qualifikation**
# - Allgemeine Hochschulreife: mehr Praxisbezug als bei Fachabitur
# - Fachgebundene Hochschulreife / Fachhochschulreife: kaum Veränderungen
#
# Hieraus lässt sich ableiten, dass Studenten mit einer allgemeinen Hochschulreife mehr Wert auf den Praxisbezug legen, als die mit fachgebundener Hochschulreife.
#
# **Studienpionier**
# - kaum Veränderungen
